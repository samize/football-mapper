# %%
import os

# %%
xml_files = [file for file in os.listdir() if file.endswith('.xml')]

# %%
def replace_shit(string):

    strings_to_replace = ['Team A', 'Team B', 'Referee', 'Goalie']
    for s in strings_to_replace:
        string = string.replace(s, 'Person')

    return string

for file in xml_files:
    with open(file, 'r') as data:
        data = replace_shit(data.read())

    with open(f'new_{file}', 'w+') as f:
        f.write(data)

# %%
with open('new_sample_1.xml', 'r') as file:
    print(file.read())
# Out:
# <annotation>
# 	<folder>original</folder>
# 	<filename>sample_1.png</filename>
# 	<path>C:\Users\bpcor\PycharmProjects\football-mapper\documentation\data\original\sample_1.png</path>
# 	<source>
# 		<database>Unknown</database>
# 	</source>
# 	<size>
# 		<width>2560</width>
# 		<height>1250</height>
# 		<depth>3</depth>
# 	</size>
# 	<segmented>0</segmented>
# 	<object>
# 		<name>Person</name>
# 		<pose>Unspecified</pose>
# 		<truncated>0</truncated>
# 		<difficult>0</difficult>
# 		<bndbox>
# 			<xmin>561</xmin>
# 			<ymin>387</ymin>
# 			<xmax>618</xmax>
# 			<ymax>534</ymax>
# 		</bndbox>
# 	</object>
# 	<object>
# 		<name>Person</name>
# 		<pose>Unspecified</pose>
# 		<truncated>0</truncated>
# 		<difficult>0</difficult>
# 		<bndbox>
# 			<xmin>1103</xmin>
# 			<ymin>262</ymin>
# 			<xmax>1159</xmax>
# 			<ymax>409</ymax>
# 		</bndbox>
# 	</object>
# 	<object>
# 		<name>Person</name>
# 		<pose>Unspecified</pose>
# 		<truncated>0</truncated>
# 		<difficult>0</difficult>
# 		<bndbox>
# 			<xmin>1006</xmin>
# 			<ymin>372</ymin>
# 			<xmax>1082</xmax>
# 			<ymax>522</ymax>
# 		</bndbox>
# 	</object>
# 	<object>
# 		<name>Person</name>
# 		<pose>Unspecified</pose>
# 		<truncated>0</truncated>
# 		<difficult>0</difficult>
# 		<bndbox>
# 			<xmin>1306</xmin>
# 			<ymin>436</ymin>
# 			<xmax>1410</xmax>
# 			<ymax>588</ymax>
# 		</bndbox>
# 	</object>
# 	<object>
# 		<name>Person</name>
# 		<pose>Unspecified</pose>
# 		<truncated>0</truncated>
# 		<difficult>0</difficult>
# 		<bndbox>
# 			<xmin>1003</xmin>
# 			<ymin>753</ymin>
# 			<xmax>1095</xmax>
# 			<ymax>981</ymax>
# 		</bndbox>
# 	</object>
# 	<object>
# 		<name>Person</name>
# 		<pose>Unspecified</pose>
# 		<truncated>0</truncated>
# 		<difficult>0</difficult>
# 		<bndbox>
# 			<xmin>1049</xmin>
# 			<ymin>993</ymin>
# 			<xmax>1170</xmax>
# 			<ymax>1226</ymax>
# 		</bndbox>
# 	</object>
# 	<object>
# 		<name>Person</name>
# 		<pose>Unspecified</pose>
# 		<truncated>0</truncated>
# 		<difficult>0</difficult>
# 		<bndbox>
# 			<xmin>39</xmin>
# 			<ymin>733</ymin>
# 			<xmax>156</xmax>
# 			<ymax>962</ymax>
# 		</bndbox>
# 	</object>
# 	<object>
# 		<name>Ball</name>
# 		<pose>Unspecified</pose>
# 		<truncated>0</truncated>
# 		<difficult>0</difficult>
# 		<bndbox>
# 			<xmin>1803</xmin>
# 			<ymin>543</ymin>
# 			<xmax>1836</xmax>
# 			<ymax>571</ymax>
# 		</bndbox>
# 	</object>
# 	<object>
# 		<name>Person</name>
# 		<pose>Unspecified</pose>
# 		<truncated>0</truncated>
# 		<difficult>0</difficult>
# 		<bndbox>
# 			<xmin>1826</xmin>
# 			<ymin>271</ymin>
# 			<xmax>1882</xmax>
# 			<ymax>419</ymax>
# 		</bndbox>
# 	</object>
# 	<object>
# 		<name>Person</name>
# 		<pose>Unspecified</pose>
# 		<truncated>0</truncated>
# 		<difficult>0</difficult>
# 		<bndbox>
# 			<xmin>1830</xmin>
# 			<ymin>397</ymin>
# 			<xmax>1896</xmax>
# 			<ymax>563</ymax>
# 		</bndbox>
# 	</object>
# 	<object>
# 		<name>Person</name>
# 		<pose>Unspecified</pose>
# 		<truncated>0</truncated>
# 		<difficult>0</difficult>
# 		<bndbox>
# 			<xmin>2131</xmin>
# 			<ymin>800</ymin>
# 			<xmax>2245</xmax>
# 			<ymax>1024</ymax>
# 		</bndbox>
# 	</object>
# 	<object>
# 		<name>Person</name>
# 		<pose>Unspecified</pose>
# 		<truncated>0</truncated>
# 		<difficult>0</difficult>
# 		<bndbox>
# 			<xmin>13</xmin>
# 			<ymin>99</ymin>
# 			<xmax>63</xmax>
# 			<ymax>218</ymax>
# 		</bndbox>
# 	</object>
# </annotation>
